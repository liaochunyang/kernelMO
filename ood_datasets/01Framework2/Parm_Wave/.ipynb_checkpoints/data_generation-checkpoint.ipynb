# %%
import os
import numpy as np
import h5py
from tqdm import tqdm
from sklearn.gaussian_process.kernels import Matern

import matplotlib.pyplot as plt

# %%
from scipy.spatial.distance import cdist

def covariance(x,y, k_sigma, l):
    sq_norm = cdist(x, y, metric='sqeuclidean')
    return np.exp(-0.5 * sq_norm / l**2) * k_sigma**2
    

def Gaussian_Process(xc, nu=1, k_sigma=1, l=1, smooth=1/2, kernel='RBF'):
    
    nx = len(xc)
    
    if kernel == 'RBF':
        # generate parametric function
        K = covariance(xc.reshape(-1,1),xc.reshape(-1,1),k_sigma, l)
    elif kernel == 'Matern':
        kernel_matern = Matern(length_scale=l, nu=smooth)
        K = kernel_matern(xc.reshape(-1,1),xc.reshape(-1,1))
    else:
        raise ValueError('Try RBF or Matern kernel')
        
    alpha = np.random.multivariate_normal(mean=np.zeros(nx), cov=K)
    
    # periodic
    slope = (alpha[-1] - alpha[0]) / (xc[-1] - xc[0])
    alpha = alpha - np.outer(slope,xc).reshape(-1)
    
    # normalize 
    min_val = np.min(alpha)
    max_val = np.max(alpha)
    
    alpha = (alpha - min_val) / (max_val - min_val)

    return nu * alpha

# %%
def generate_initial_conditions(xc, n_samples, rng, amp_low=0, amp_up=1, k_tot=4, n_modes=2, mode='sin', 
                                nu=1, k_sigma=1, l=1):
    """Generate random sinusoidal initial conditions, normalized to [0, 1].
    Mimics the init_multi function from the original codebase."""
    nx = len(xc)
    x_len = xc[-1] - xc[0]
    u_all = np.zeros((n_samples, nx), dtype=np.float32)
    
    if mode == 'sin':
        for i in range(n_samples):
            # Select random wavenumber modes
            selected_k = rng.choice(k_tot, size=n_modes, replace=False) + 1
            u = np.zeros(nx, dtype=np.float64)
            for k in selected_k:
                amp = rng.uniform(amp_low, amp_up)
                phase = rng.uniform(0, 2 * np.pi)
                wavenumber = 2 * np.pi * k / x_len
                u += amp * np.sin(wavenumber * xc + phase)
            # Random sign flip
            if rng.random() < 0.5:
                u = -u
            # Remove linear trend for periodicity
            slope = (u[-1] - u[0]) / x_len
            u -= slope * xc
            # Normalize to [0, 1]
            u_min, u_max = u.min(), u.max()
            if u_max - u_min > 1e-10:
                u = (u - u_min) / (u_max - u_min)
            u_all[i] = u.astype(np.float32)
            
            
    elif mode == 'GP':
        
        for i in range(n_samples):
            u_all[i] = Gaussian_Process(xc, nu, k_sigma, l)
           
    else:
        raise ValueError('Wrong initial condition mode')
        
    return u_all

# %%
def solve_parametric_wave(u0, alpha_t, x_range, t_range, nx, t_num, CFL=0.4):
    """
    Solve:
        u_tt = alpha(t)^2 u_xx
    with periodic BC and u_t(0,x)=0
    """

    dx = x_range / nx
    dt_save = t_range / (t_num - 1)

    # periodic Laplacian
    def lap(u):
        return (np.roll(u, -1) - 2*u + np.roll(u, 1)) / dx**2

    # initial state
    u = u0.copy()
    v = np.zeros_like(u0)

    uu = np.zeros((t_num, nx), dtype=np.float32)
    uu[0] = u

    t = 0.0
    i_save = 1
    t_save = dt_save

    while i_save < t_num:

        a = alpha_t(t) if callable(alpha_t) else alpha_t[i_save - 1]

        # CFL condition
        dt = min(CFL * dx / (abs(a) + 1e-12), t_save - t)

        # leapfrog
        v += 0.5 * dt * (a**2) * lap(u)
        u += dt * v
        v += 0.5 * dt * (a**2) * lap(u)

        t += dt

        if t >= t_save - 1e-12:
            uu[i_save] = u.astype(np.float32)
            i_save += 1
            t_save = i_save * dt_save

    return uu

# %%
def generate_wave_dataset(data_dir, n_param_sets, ics_per_param, 
                          k_sigma_coef, nu_coef, l_coef, smooth_coef, kernel_coef,
                          x_range, t_range, nx, t_num, file_name, 
                          amp_low = 0, amp_up=1, k_tot=4, n_modes=2,
                          mode='sin', nu=1, k_sigma=1, l=1, seed=42):
    
    
    os.makedirs(data_dir, exist_ok=True)
    h5_path = os.path.join(data_dir, file_name)
    
    rng = np.random.default_rng(seed)
    dx = x_range / nx
    dt = t_range / t_num
    xc = np.linspace(0, x_range, nx + 1)[:-1] + 0.5 * dx
    tc = np.linspace(0, t_range, t_num+1)[:-1] + 0.5 * dt
    
    total = n_param_sets * ics_per_param
    all_solutions = np.zeros((total, t_num, nx, 1), dtype=np.float32)
    all_coeffs = np.zeros((total, t_num), dtype=np.float32)
    idx = 0
    failed = 0
    
    for p in tqdm(range(n_param_sets), desc="Generating data"):
        # coefficient function from Gaussian Process
        coeff = Gaussian_Process(xe, nu_coef, k_sigma_coef, l_coef, smooth_coef, kernel_coef) 

        # Generate ICs for this parameter set
        ics = generate_initial_conditions(xc, ics_per_param * 2, rng, amp_low = amp_low, amp_up = amp_up,
                                         k_tot = k_tot, n_modes = n_modes, mode = mode, 
                                          nu = nu, k_sigma = k_sigma, l=l)  # generate extra in case some fail

        count = 0
        for ic_idx in range(len(ics)):
            if count >= ics_per_param:
                break
            try:
                sol = solve_parametric_wave(ics[ic_idx].astype(np.float64), coeff, 
                                      x_range, t_range, nx, t_num, CFL=0.4)
                
                norm = np.linalg.norm(sol)
                if norm < 2000 and norm > 1 and np.all(np.isfinite(sol)):
                    all_solutions[idx, :, :, 0] = sol
                    all_coeffs[idx] = coeff
                    idx += 1
                    count += 1
                else:
                    failed += 1
            except Exception:
                failed += 1


    # Trim to actual size
    all_solutions = all_solutions[:idx]
    all_coeffs = all_coeffs[:idx]

    # Save
    with h5py.File(h5_path, "w") as hf:
        hf.create_dataset("data", data=all_solutions)
        hf.create_dataset("coeffs", data=all_coeffs)

    print(f"Saved {idx} samples to {h5_path}")
    return h5_path

# %%
# ============ Data / PDE config ============
DATA_DIR        = "dataset_simple/"   # where to save/load generated data
T_NUM           = 64                  # timesteps
X_NUM           = 128                 # spatial grid points
T_RANGE         = (0.0, 2.0)
X_RANGE         = (0.0, 2.0)
INPUT_LEN       = 1                   # input timesteps
INPUT_STEP      = 1
OUTPUT_STEP     = 2
NORMALIZE       = True

# Generation parameters
N_PARAM_SETS    = 280                 # number of different PDE coefficient sets
ICS_PER_PARAM   = 50                  # initial conditions per coefficient set
TOTAL_SAMPLES   = N_PARAM_SETS * ICS_PER_PARAM  # 2000 total

# Coefficient Functions
K_SIGMA_COEF = 1
NU_COEF      = 1
L_COEF       = 1
SMOOTH_COEF  = 1/2
KERNEL_COEF  = 'RBF'
# Initial condition: default setting
AMP_LOW     = 0
AMP_UP      = 1 
K_TOT       = 4
N_MODES     = 2
MODE        = 'sin'
NU          = 1
K_SIGMA     = 1
L           = 1
SEED        = 42

# %%
# Generate or load data
file_name = 'solutions.h5'
h5_path = os.path.join(DATA_DIR, file_name)

if os.path.exists(h5_path):
    print(f"Data already exists at {h5_path}, loading...")
    with h5py.File(h5_path, "r") as hf:
        print(f"  Solutions shape: {hf['data'].shape}")
        print(f"  Coefficients shape: {hf['coeffs'].shape}")
else:
    print("Generating conservation law dataset...")
    generate_wave_dataset(DATA_DIR, N_PARAM_SETS, ICS_PER_PARAM, 
                          K_SIGMA_COEF, NU_COEF, L_COEF, SMOOTH_COEF, KERNEL_COEF,
                        X_RANGE[1], T_RANGE[1], X_NUM, T_NUM, file_name, 
                         amp_low = AMP_LOW, amp_up=AMP_UP, k_tot=K_TOT, n_modes=N_MODES,
                               mode=MODE, nu=NU, k_sigma=K_SIGMA, l=L, seed=SEED)
# Out:
# Generating conservation law dataset...
# Generating data: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 280/280 [01:19<00:00,  3.52it/s]
# Saved 14000 samples to dataset_simple/solutions.h5

# %% [markdown]
# # Out-of-distribution Datasets
#
# #### OOD1: Parametric function (variance)

# %%
# ============ Data / PDE config ============
DATA_DIR        = "dataset_simple/"   # where to save/load generated data
T_NUM           = 64                  # timesteps
X_NUM           = 128                 # spatial grid points
T_RANGE         = (0.0, 2.0)
X_RANGE         = (0.0, 2.0)
INPUT_LEN       = 1                   # input timesteps
INPUT_STEP      = 1
OUTPUT_STEP     = 2
NORMALIZE       = True

# Generation parameters
N_PARAM_SETS    = 80                 # number of different PDE coefficient sets
ICS_PER_PARAM   = 50                  # initial conditions per coefficient set
TOTAL_SAMPLES   = N_PARAM_SETS * ICS_PER_PARAM  # 2000 total

# Coefficient Functions
K_SIGMA_COEF = 0.1
NU_COEF      = 1
L_COEF       = 1
SMOOTH_COEF  = 1/2
KERNEL_COEF  = 'RBF'
# Initial condition: default setting
AMP_LOW     = 0
AMP_UP      = 1 
K_TOT       = 4
N_MODES     = 2
MODE        = 'sin'
NU          = 1
K_SIGMA     = 1
L           = 1
SEED        = 42

# %%
# Generate or load data
file_name = 'ood_par_var.h5'
h5_path = os.path.join(DATA_DIR, file_name)

if os.path.exists(h5_path):
    print(f"Data already exists at {h5_path}, loading...")
    with h5py.File(h5_path, "r") as hf:
        print(f"  Solutions shape: {hf['data'].shape}")
        print(f"  Coefficients shape: {hf['coeffs'].shape}")
else:
    print("Generating conservation law dataset...")
    generate_wave_dataset(DATA_DIR, N_PARAM_SETS, ICS_PER_PARAM, 
                          K_SIGMA_COEF, NU_COEF, L_COEF, SMOOTH_COEF, KERNEL_COEF,
                        X_RANGE[1], T_RANGE[1], X_NUM, T_NUM, file_name, 
                         amp_low = AMP_LOW, amp_up=AMP_UP, k_tot=K_TOT, n_modes=N_MODES,
                               mode=MODE, nu=NU, k_sigma=K_SIGMA, l=L, seed=SEED)

# %% [markdown]
# #### OOD2: Parametric function (sclae)

# %%
# ============ Data / PDE config ============
DATA_DIR        = "dataset_simple/"   # where to save/load generated data
T_NUM           = 64                  # timesteps
X_NUM           = 128                 # spatial grid points
T_RANGE         = (0.0, 2.0)
X_RANGE         = (0.0, 2.0)
INPUT_LEN       = 1                   # input timesteps
INPUT_STEP      = 1
OUTPUT_STEP     = 2
NORMALIZE       = True

# Generation parameters
N_PARAM_SETS    = 80                 # number of different PDE coefficient sets
ICS_PER_PARAM   = 50                  # initial conditions per coefficient set
TOTAL_SAMPLES   = N_PARAM_SETS * ICS_PER_PARAM  # 2000 total

# Coefficient Functions
K_SIGMA_COEF = 1
NU_COEF      = 1
L_COEF       = 0.1
SMOOTH_COEF  = 1/2
KERNEL_COEF  = 'RBF'
# Initial condition: default setting
AMP_LOW     = 0
AMP_UP      = 1 
K_TOT       = 4
N_MODES     = 2
MODE        = 'sin'
NU          = 1
K_SIGMA     = 1
L           = 1
SEED        = 42

# %%
# Generate or load data
file_name = 'ood_par_scale.h5'
h5_path = os.path.join(DATA_DIR, file_name)

if os.path.exists(h5_path):
    print(f"Data already exists at {h5_path}, loading...")
    with h5py.File(h5_path, "r") as hf:
        print(f"  Solutions shape: {hf['data'].shape}")
        print(f"  Coefficients shape: {hf['coeffs'].shape}")
else:
    print("Generating conservation law dataset...")
    generate_wave_dataset(DATA_DIR, N_PARAM_SETS, ICS_PER_PARAM, 
                          K_SIGMA_COEF, NU_COEF, L_COEF, SMOOTH_COEF, KERNEL_COEF,
                        X_RANGE[1], T_RANGE[1], X_NUM, T_NUM, file_name, 
                         amp_low = AMP_LOW, amp_up=AMP_UP, k_tot=K_TOT, n_modes=N_MODES,
                               mode=MODE, nu=NU, k_sigma=K_SIGMA, l=L, seed=SEED)

# %% [markdown]
# ## OOD3: Parametric function (Matern)

# %%
# ============ Data / PDE config ============
DATA_DIR        = "dataset_simple/"   # where to save/load generated data
T_NUM           = 64                  # timesteps
X_NUM           = 128                 # spatial grid points
T_RANGE         = (0.0, 2.0)
X_RANGE         = (0.0, 2.0)
INPUT_LEN       = 1                   # input timesteps
INPUT_STEP      = 1
OUTPUT_STEP     = 2
NORMALIZE       = True

# Generation parameters
N_PARAM_SETS    = 80                 # number of different PDE coefficient sets
ICS_PER_PARAM   = 50                  # initial conditions per coefficient set
TOTAL_SAMPLES   = N_PARAM_SETS * ICS_PER_PARAM  # 2000 total

# Coefficient Functions
K_SIGMA_COEF = 1
NU_COEF      = 1
L_COEF       = 1
SMOOTH_COEF  = 1/2
KERNEL_COEF  = 'Matern'
# Initial condition: default setting
AMP_LOW     = 0
AMP_UP      = 1 
K_TOT       = 4
N_MODES     = 2
MODE        = 'sin'
NU          = 1
K_SIGMA     = 1
L           = 1
SEED        = 42

# %%
# Generate or load data
file_name = 'ood_par_kernel.h5'
h5_path = os.path.join(DATA_DIR, file_name)

if os.path.exists(h5_path):
    print(f"Data already exists at {h5_path}, loading...")
    with h5py.File(h5_path, "r") as hf:
        print(f"  Solutions shape: {hf['data'].shape}")
        print(f"  Coefficients shape: {hf['coeffs'].shape}")
else:
    print("Generating conservation law dataset...")
    generate_wave_dataset(DATA_DIR, N_PARAM_SETS, ICS_PER_PARAM, 
                          K_SIGMA_COEF, NU_COEF, L_COEF, SMOOTH_COEF, KERNEL_COEF,
                        X_RANGE[1], T_RANGE[1], X_NUM, T_NUM, file_name, 
                         amp_low = AMP_LOW, amp_up=AMP_UP, k_tot=K_TOT, n_modes=N_MODES,
                               mode=MODE, nu=NU, k_sigma=K_SIGMA, l=L, seed=SEED)

# %% [markdown]
# ## OOD4: Initial condition (amplitude and number of sine functions)

# %%
# ============ Data / PDE config ============
DATA_DIR        = "dataset_simple/"   # where to save/load generated data
T_NUM           = 64                  # timesteps
X_NUM           = 128                 # spatial grid points
T_RANGE         = (0.0, 2.0)
X_RANGE         = (0.0, 2.0)
INPUT_LEN       = 1                   # input timesteps
INPUT_STEP      = 1
OUTPUT_STEP     = 2
NORMALIZE       = True

# Generation parameters
N_PARAM_SETS    = 80                 # number of different PDE coefficient sets
ICS_PER_PARAM   = 50                  # initial conditions per coefficient set
TOTAL_SAMPLES   = N_PARAM_SETS * ICS_PER_PARAM  # 2000 total

# Coefficient Functions
K_SIGMA_COEF = 1
NU_COEF      = 1
L_COEF       = 1
SMOOTH_COEF  = 1/2
KERNEL_COEF  = 'RBF'
# Initial condition: 
AMP_LOW     = -2         # 0 -> -2
AMP_UP      = 2          # 1 -> 2 
K_TOT       = 8          # 4 -> 8
N_MODES     = 4          # 2 -> 4
MODE        = 'sin'
NU          = 1
K_SIGMA     = 1
L           = 1
SEED        = 42

# %%
# Generate or load data
file_name = 'ood_init.h5'
h5_path = os.path.join(DATA_DIR, file_name)

if os.path.exists(h5_path):
    print(f"Data already exists at {h5_path}, loading...")
    with h5py.File(h5_path, "r") as hf:
        print(f"  Solutions shape: {hf['data'].shape}")
        print(f"  Coefficients shape: {hf['coeffs'].shape}")
else:
    print("Generating conservation law dataset...")
    generate_wave_dataset(DATA_DIR, N_PARAM_SETS, ICS_PER_PARAM, 
                          K_SIGMA_COEF, NU_COEF, L_COEF, SMOOTH_COEF, KERNEL_COEF,
                        X_RANGE[1], T_RANGE[1], X_NUM, T_NUM, file_name, 
                         amp_low = AMP_LOW, amp_up=AMP_UP, k_tot=K_TOT, n_modes=N_MODES,
                               mode=MODE, nu=NU, k_sigma=K_SIGMA, l=L, seed=SEED)

# %% [markdown]
# ## OOD5: Parametric function (scale) + initial condition (amplitudes and number of sine functions)

# %%
# ============ Data / PDE config ============
DATA_DIR        = "dataset_simple/"   # where to save/load generated data
T_NUM           = 64                  # timesteps
X_NUM           = 128                 # spatial grid points
T_RANGE         = (0.0, 2.0)
X_RANGE         = (0.0, 2.0)
INPUT_LEN       = 1                   # input timesteps
INPUT_STEP      = 1
OUTPUT_STEP     = 2
NORMALIZE       = True

# Generation parameters
N_PARAM_SETS    = 80                  # number of different PDE coefficient sets
ICS_PER_PARAM   = 50                  # initial conditions per coefficient set
TOTAL_SAMPLES   = N_PARAM_SETS * ICS_PER_PARAM  # 2000 total

# Coefficient Functions
K_SIGMA_COEF = 1
NU_COEF      = 0.01
L_COEF       = 0.1
SMOOTH_COEF  = 1/2
KERNEL_COEF  = 'RBF'
# Initial condition: 
AMP_LOW     = -2         # 0 -> -2
AMP_UP      = 2          # 1 -> 2 
K_TOT       = 8          # 4 -> 8
N_MODES     = 4          # 2 -> 4
MODE        = 'sin'
NU          = 1
K_SIGMA     = 1
L           = 1
SEED        = 42

# %%
# Generate or load data
file_name = 'ood_par_init.h5'
h5_path = os.path.join(DATA_DIR, file_name)

if os.path.exists(h5_path):
    print(f"Data already exists at {h5_path}, loading...")
    with h5py.File(h5_path, "r") as hf:
        print(f"  Solutions shape: {hf['data'].shape}")
        print(f"  Coefficients shape: {hf['coeffs'].shape}")
else:
    print("Generating conservation law dataset...")
    generate_wave_dataset(DATA_DIR, N_PARAM_SETS, ICS_PER_PARAM, 
                          K_SIGMA_COEF, NU_COEF, L_COEF, SMOOTH_COEF, KERNEL_COEF,
                        X_RANGE[1], T_RANGE[1], X_NUM, T_NUM, file_name, 
                         amp_low = AMP_LOW, amp_up=AMP_UP, k_tot=K_TOT, n_modes=N_MODES,
                               mode=MODE, nu=NU, k_sigma=K_SIGMA, l=L, seed=SEED)
